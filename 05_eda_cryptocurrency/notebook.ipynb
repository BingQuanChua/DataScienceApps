# %% [markdown]
# Web scraping from cryptocurrency data from Coin Market Cap
#
# Source: [Coin Market Cap](https://coinmarketcap.com)
#
# Tutorial: [Data Science Web Apps Tutorial by Data Professor](https://www.youtube.com/watch?v=JwSS70SZdyM&list=PLRpb1EfB9cjuOFw_ZVmeqlCgdhYjdbBMO&index=13&ab_channel=freeCodeCamp.org)

# %% [markdown]
# # Web Scraping

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json

# %%
cmc = requests.get('https://coinmarketcap.com')
soup = BeautifulSoup(cmc.content, 'html.parser')

data = soup.find('script', id='__NEXT_DATA__', type='application/json')
    
coin_data = json.loads(data.contents[0])
listings = coin_data['props']['initialState']['cryptocurrency']['listingLatest']['data']

# %%
# printing out one listing
listings[0]
# Out:
# {'id': 1,
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'slug': 'bitcoin',
#  'tags': ['mineable',
#   'pow',
#   'sha-256',
#   'store-of-value',
#   'state-channels',
#   'coinbase-ventures-portfolio',
#   'three-arrows-capital-portfolio',
#   'polychain-capital-portfolio',
#   'binance-labs-portfolio',
#   'arrington-xrp-capital',
#   'blockchain-capital-portfolio',
#   'boostvc-portfolio',
#   'cms-holdings-portfolio',
#   'dcg-portfolio',
#   'dragonfly-capital-portfolio',
#   'electric-capital-portfolio',
#   'fabric-ventures-portfolio',
#   'framework-ventures',
#   'galaxy-digital-portfolio',
#   'huobi-capital',
#   'alameda-research-portfolio',
#   'a16z-portfolio',
#   '1confirmation-portfolio',
#   'winklevoss-capital',
#   'usv-portfolio',
#   'placeholder-ventures-portfolio',
#   'pantera-capital-portfolio',
#   'multicoin-capital-portfolio',
#   'paradigm-xzy-screener'],
#  'cmcRank': 1,
#  'marketPairCount': 9187,
#  'circulatingSupply': 18746181,
#  'totalSupply': 18746181,
#  'maxSupply': 21000000,
#  'ath': 64863.0989077,
#  'atl': 65.52600098,
#  'high24h': 33939.58869924,
#  'low24h': 32770.68078046,
#  'isActive': 1,
#  'lastUpdated': '2021-07-02T09:09:02.000Z',
#  'dateAdded': '2013-04-28T00:00:00.000Z',
#  'quotes': [{'name': 'BTC',
#    'price': 1,
#    'volume24h': 992386.21955776,
#    'volume7d': 12797853.56250512,
#    'volume30d': 36593824.17134862,
#    'marketCap': 18746181,
#    'percentChange1h': 0,
#    'percentChange24h': 0,
#    'percentChange7d': 0,
#    'lastUpdated': '2021-07-02T09:09:02.000Z',
#    'percentChange30d': 0,
#    'percentChange60d': 0,
#    'percentChange90d': 0,
#    'fullyDilluttedMarketCap': 699224336158.62,
#    'dominance': 45.723,
#    'turnover': 0.05293805,
#    'ytdPriceChangePercentage': 13.3527},
#   {'name': 'ETH',
#    'price': 16.2476342,
#    'volume24h': 16123928.28104882,
#    'volume7d': 207934843.23588738,
#    'volume30d': 594563069.1355989,
#    'marketCap': 304581091.54544497,
#    'percentChange1h': 0.316423,
#    'percentChange24h': 3.220519,
#    'percentChange7d': -8.226618,
#    'lastUpdated': '2021-07-02T09:09:02.000Z',
#    'percentChange30d': -10.99768416,
#    'percentChange60d': -42.99819045,
#    'percentChange90d': -43.84763003,
#    'fullyDilluttedMarketCap': 699224336158.62,
#    'dominance': 45.723,
#    'turnover': 0.05293805,
#    'ytdPriceChangePercentage': 13.3527},
#   {'name': 'USD',
#    'price': 33296.39695993446,
#    'volume24h': 33042885503.963833,
#    'volume7d': 426122412452.2818,
#    'volume30d': 1218442495891.2683,
#    'marketCap': 624180284058.7811,
#    'percentChange1h': -0.13689833,
#    'percentChange24h': -0.6741857,
#    'percentChange7d': -2.93115327,
#    'lastUpdated': '2021-07-02T09:09:02.000Z',
#    'percentChange30d': -10.99768416,
#    'percentChange60d': -42.99819045,
#    'percentChange90d': -43.84763003,
#    'fullyDilluttedMarketCap': 699224336158.62,
#    'dominance': 45.723,
#    'turnover': 0.05293805,
#    'ytdPriceChangePercentage': 13.3527}],
#  'isAudited': False,
#  'rank': 1,
#  'hasFilters': False,
#  'noLazyLoad': True,
#  'quote': {'BTC': {'name': 'BTC',
#    'price': 1,
#    'volume24h': 992386.21955776,
#    'volume7d': 12797853.56250512,
#    'volume30d': 36593824.17134862,
#    'marketCap': 18746181,
#    'percentChange1h': 0,
#    'percentChange24h': 0,
#    'percentChange7d': 0,
#    'lastUpdated': '2021-07-02T09:09:02.000Z',
#    'percentChange30d': 0,
#    'percentChange60d': 0,
#    'percentChange90d': 0,
#    'fullyDilluttedMarketCap': 699224336158.62,
#    'dominance': 45.723,
#    'turnover': 0.05293805,
#    'ytdPriceChangePercentage': 13.3527},
#   'ETH': {'name': 'ETH',
#    'price': 16.2476342,
#    'volume24h': 16123928.28104882,
#    'volume7d': 207934843.23588738,
#    'volume30d': 594563069.1355989,
#    'marketCap': 304581091.54544497,
#    'percentChange1h': 0.316423,
#    'percentChange24h': 3.220519,
#    'percentChange7d': -8.226618,
#    'lastUpdated': '2021-07-02T09:09:02.000Z',
#    'percentChange30d': -10.99768416,
#    'percentChange60d': -42.99819045,
#    'percentChange90d': -43.84763003,
#    'fullyDilluttedMarketCap': 699224336158.62,
#    'dominance': 45.723,
#    'turnover': 0.05293805,
#    'ytdPriceChangePercentage': 13.3527},
#   'USD': {'name': 'USD',
#    'price': 33296.39695993446,
#    'volume24h': 33042885503.963833,
#    'volume7d': 426122412452.2818,
#    'volume30d': 1218442495891.2683,
#    'marketCap': 624180284058.7811,
#    'percentChange1h': -0.13689833,
#    'percentChange24h': -0.6741857,
#    'percentChange7d': -2.93115327,
#    'lastUpdated': '2021-07-02T09:09:02.000Z',
#    'percentChange30d': -10.99768416,
#    'percentChange60d': -42.99819045,
#    'percentChange90d': -43.84763003,
#    'fullyDilluttedMarketCap': 699224336158.62,
#    'dominance': 45.723,
#    'turnover': 0.05293805,
#    'ytdPriceChangePercentage': 13.3527}},
#  'hasAdListingButton': True}

# %% [markdown]
# The website changed the name of the key, hence the old code from the tutorial does not work.

# %%
def load_data():
    cmc = requests.get('https://coinmarketcap.com')
    soup = BeautifulSoup(cmc.content, 'html.parser')
    currency_price_unit = 'USD'

    data = soup.find('script', id='__NEXT_DATA__', type='application/json')
    coins = {}
    coin_data = json.loads(data.contents[0])
    listings = coin_data['props']['initialState']['cryptocurrency']['listingLatest']['data']

    for i in listings:
      coins[str(i['id'])] = i['slug']

    coin_name = []
    coin_symbol = []
    market_cap = []
    percent_change_1h = []
    percent_change_24h = []
    percent_change_7d = []
    price = []
    volume_24h = []

    for i in listings: 
        coin_name.append(i['slug'])
        coin_symbol.append(i['symbol'])
        price.append(i['quote'][currency_price_unit]['price'])
        percent_change_1h.append(i['quote'][currency_price_unit]['percentChange1h']) # the website change the key name
        percent_change_24h.append(i['quote'][currency_price_unit]['percentChange24h'])
        percent_change_7d.append(i['quote'][currency_price_unit]['percentChange7d'])
        market_cap.append(i['quote'][currency_price_unit]['marketCap'])
        volume_24h.append(i['quote'][currency_price_unit]['volume24h'])
        

    df = pd.DataFrame(columns=['coin_name', 'coin_symbol', 'market_cap', 'percent_change_1h', 'percent_change_24h', 'percent_change_7d', 'price', 'volume_24h'])
    df['coin_name'] = coin_name
    df['coin_symbol'] = coin_symbol
    df['price'] = price
    df['percent_change_1h'] = percent_change_1h
    df['percent_change_24h'] = percent_change_24h
    df['percent_change_7d'] = percent_change_7d
    df['market_cap'] = market_cap
    df['volume_24h'] = volume_24h
    return df

# %%
df = load_data()
df
# Out:
#        coin_name coin_symbol    market_cap  percent_change_1h  \
# 0        bitcoin         BTC  6.241803e+11          -0.136898
# 1       ethereum         ETH  2.387977e+11          -0.451891
# 2         tether        USDT  6.240191e+10           0.004256
# 3   binance-coin         BNB  4.294408e+10          -0.583587
# 4        cardano         ADA  4.195351e+10           0.297806
# ..           ...         ...           ...                ...
# 95            0x         ZRX  5.631966e+08          -0.782310
# 96        fantom         FTM  5.599718e+08          -0.412596
# 97           omg         OMG  5.540938e+08          -0.488088
# 98          husd        HUSD  5.540388e+08          -0.017008
# 99           uma         UMA  5.328383e+08           0.396725
#
#     percent_change_24h  percent_change_7d         price    volume_24h
# 0            -0.674186          -2.931153  33296.396960  3.304289e+10
# 1            -3.773189           5.770154   2049.307398  2.503999e+10
# 2             0.018275           0.022471      1.000449  5.032566e+10
# 3            -2.597234          -5.113145    279.888372  1.269051e+09
# 4            -0.581604          -2.196197      1.313250  1.879520e+09
# ..                 ...                ...           ...           ...
# 95           -7.890894           2.697203      0.666250  4.512286e+07
# 96           -1.526639          -3.446910      0.220028  3.508396e+07
# 97           -4.721405           4.278313      3.950887  1.536432e+08
# 98            0.024091           0.016867      1.000258  4.516387e+08
# 99           -7.684860          -0.529769      8.636460  2.744544e+07
#
# [100 rows x 8 columns]

# %%
df_change = pd.concat([df.coin_symbol, df.percent_change_1h, df.percent_change_24h, df.percent_change_7d], axis=1)
df_change = df_change.set_index('coin_symbol')
df_change['positive_percent_change_1h'] = df_change['percent_change_1h'] > 0
df_change['positive_percent_change_24h'] = df_change['percent_change_24h'] > 0
df_change['positive_percent_change_7d'] = df_change['percent_change_7d'] > 0
df_change
# Out:
#              percent_change_1h  percent_change_24h  percent_change_7d  \
# coin_symbol
# BTC                  -0.136898           -0.674186          -2.931153
# ETH                  -0.451891           -3.773189           5.770154
# USDT                  0.004256            0.018275           0.022471
# BNB                  -0.583587           -2.597234          -5.113145
# ADA                   0.297806           -0.581604          -2.196197
# ...                        ...                 ...                ...
# ZRX                  -0.782310           -7.890894           2.697203
# FTM                  -0.412596           -1.526639          -3.446910
# OMG                  -0.488088           -4.721405           4.278313
# HUSD                 -0.017008            0.024091           0.016867
# UMA                   0.396725           -7.684860          -0.529769
#
#              positive_percent_change_1h  positive_percent_change_24h  \
# coin_symbol
# BTC                               False                        False
# ETH                               False                        False
# USDT                               True                         True
# BNB                               False                        False
# ADA                                True                        False
# ...                                 ...                          ...
# ZRX                               False                        False
# FTM                               False                        False
# OMG                               False                        False
# HUSD                              False                         True
# UMA                                True                        False
#
#              positive_percent_change_7d
# coin_symbol
# BTC                               False
# ETH                                True
# USDT                               True
# BNB                               False
# ADA                               False
# ...                                 ...
# ZRX                                True
# FTM                               False
# OMG                                True
# HUSD                               True
# UMA                               False
#
# [100 rows x 6 columns]
